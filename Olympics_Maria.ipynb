# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Read csv files
athletes_bio_csv = pd.read_csv("https://raw.githubusercontent.com/josephwccheng/olympedia_web_scraping/main/data/Olympic_Athlete_Bio.csv")
athlete_results_csv = pd.read_csv("https://raw.githubusercontent.com/josephwccheng/olympedia_web_scraping/main/data/Olympic_Athlete_Event_Results.csv")
medals_csv = pd.read_csv("Resources/Olympic_Games_Medal_Tally.csv")
countries_csv = pd.read_csv("Resources/Olympics_Country.csv")
olympics_games_csv = pd.read_csv("Resources/Olympics_Games.csv")

# %%
# Merge athletes results and bio
bio_results_csv = pd.merge(athlete_results_csv, athletes_bio_csv, on='athlete_id', how='outer')
bio_results_csv.head()
# Out:
#                 edition  edition_id country_noc_x   sport           event  \
# 0  1912 Summer Olympics           6           FRA  Tennis    Singles, Men
# 1  1912 Summer Olympics           6           FRA  Tennis    Doubles, Men
# 2  1920 Summer Olympics           7           FRA  Tennis    Singles, Men
# 3  1920 Summer Olympics           7           FRA  Tennis    Doubles, Men
# 4  1920 Summer Olympics           7           FRA  Tennis  Doubles, Mixed
#
#    result_id                athlete  athlete_id  pos medal  isTeamSport  \
# 0      44337  Jean-François Blanchy           1  =17   NaN        False
# 1      44412  Jean-François Blanchy           1  DNS   NaN         True
# 2      44578  Jean-François Blanchy           1  =32   NaN        False
# 3      44626  Jean-François Blanchy           1    4   NaN         True
# 4      44692  Jean-François Blanchy           1   =8   NaN         True
#
#                     name   sex              born  height weight  country  \
# 0  Jean-François Blanchy  Male  12 December 1886     NaN    NaN   France
# 1  Jean-François Blanchy  Male  12 December 1886     NaN    NaN   France
# 2  Jean-François Blanchy  Male  12 December 1886     NaN    NaN   France
# 3  Jean-François Blanchy  Male  12 December 1886     NaN    NaN   France
# 4  Jean-François Blanchy  Male  12 December 1886     NaN    NaN   France
#
#   country_noc_y                                        description  \
# 0           FRA  Jean-François Blanchy competed at the 1912 and...
# 1           FRA  Jean-François Blanchy competed at the 1912 and...
# 2           FRA  Jean-François Blanchy competed at the 1912 and...
# 3           FRA  Jean-François Blanchy competed at the 1912 and...
# 4           FRA  Jean-François Blanchy competed at the 1912 and...
#
#   special_notes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# Filter to only summer athletes
summer_bio_results_csv = bio_results_csv.loc[(bio_results_csv['edition'].str.contains('Summer')), ['edition', 'edition_id', 'country_noc_x', 'sport', 'event', 'athlete', 'athlete_id', 'medal', 'name', 'sex', 'born', 'height', 'weight', 'country', 'country_noc_y']]
summer_bio_results_csv
# Out:
#                      edition  edition_id country_noc_x             sport  \
# 0       1912 Summer Olympics           6           FRA            Tennis
# 1       1912 Summer Olympics           6           FRA            Tennis
# 2       1920 Summer Olympics           7           FRA            Tennis
# 3       1920 Summer Olympics           7           FRA            Tennis
# 4       1920 Summer Olympics           7           FRA            Tennis
# ...                      ...         ...           ...               ...
# 314902  1900 Summer Olympics           2           GBR           Cricket
# 314903  1900 Summer Olympics           2           GBR           Cricket
# 314904  1900 Summer Olympics           2           GBR           Cricket
# 314905  1948 Summer Olympics          12           IRL         Athletics
# 314906  1924 Summer Olympics           8           NED  Art Competitions
#
#                   event                athlete  athlete_id medal  \
# 0          Singles, Men  Jean-François Blanchy           1   NaN
# 1          Doubles, Men  Jean-François Blanchy           1   NaN
# 2          Singles, Men  Jean-François Blanchy           1   NaN
# 3          Doubles, Men  Jean-François Blanchy           1   NaN
# 4        Doubles, Mixed  Jean-François Blanchy           1   NaN
# ...                 ...                    ...         ...   ...
# 314902     Cricket, Men           E. P. Daniel     3100007  Gold
# 314903     Cricket, Men          J. M. Willcox     3100008  Gold
# 314904     Cricket, Men            G. P. Brook     3100009  Gold
# 314905  800 metres, Men           Seamus Kelly     3100010   NaN
# 314906      Music, Open              Jaap Kool    22000000   NaN
#
#                          name   sex              born  height weight  \
# 0       Jean-François Blanchy  Male  12 December 1886     NaN    NaN
# 1       Jean-François Blanchy  Male  12 December 1886     NaN    NaN
# 2       Jean-François Blanchy  Male  12 December 1886     NaN    NaN
# 3       Jean-François Blanchy  Male  12 December 1886     NaN    NaN
# 4       Jean-François Blanchy  Male  12 December 1886     NaN    NaN
# ...                       ...   ...               ...     ...    ...
# 314902           E. P. Daniel  Male               NaN     NaN    NaN
# 314903          J. M. Willcox  Male               NaN     NaN    NaN
# 314904            G. P. Brook  Male               NaN     NaN    NaN
# 314905           Seamus Kelly  Male               NaN     NaN    NaN
# 314906              Jaap Kool  Male  31 December 1890     NaN    NaN
#
#                country country_noc_y
# 0               France           FRA
# 1               France           FRA
# 2               France           FRA
# 3               France           FRA
# 4               France           FRA
# ...                ...           ...
# 314902   Great Britain           GBR
# 314903   Great Britain           GBR
# 314904   Great Britain           GBR
# 314905         Ireland           IRL
# 314906     Netherlands           NED
#
# [252859 rows x 15 columns]

# %%
# Lenght of merged bio_results_csv
len(summer_bio_results_csv)
# Out:
# 252859

# %%
# Change born column to make it a date format column
# Copy the born column to original_born
summer_bio_results_csv['original_born'] = summer_bio_results_csv['born']

# Check if the date is only a year entry and enter NaT in the born column
# Define a function to check string length and identify if its only a year
def is_year_only(date_str):
    if isinstance(date_str, str):
        date_parts = date_str.split()
        return len(date_parts) == 1
    else:
        return False

# Apply the function to original_born
summer_bio_results_csv['is_year_date'] = summer_bio_results_csv['original_born'].apply(is_year_only)

# If it's only a year enter NaT in the born column
summer_bio_results_csv.loc[summer_bio_results_csv['is_year_date'], 'born'] = pd.NaT

# Drop the column that checked the length of the string and original_born
summer_bio_results_csv = summer_bio_results_csv.drop(['is_year_date', 'original_born'], axis=1)

# Copy the born column to copy_born
summer_bio_results_csv['copy_born'] = summer_bio_results_csv['born']

# Define a function to reformat all valid born dates to calculate age
def convert_to_datetime(date_str):
    try:
        return pd.to_datetime(date_str)
    except ValueError:
        return pd.NaT

# Apply the function to copy_born
summer_bio_results_csv['born'] = summer_bio_results_csv['copy_born'].apply(convert_to_datetime)

# Drop the column copy_born
summer_bio_results_csv = summer_bio_results_csv.drop('copy_born', axis=1)
summer_bio_results_csv
# Out:
#                      edition  edition_id country_noc_x             sport  \
# 0       1912 Summer Olympics           6           FRA            Tennis
# 1       1912 Summer Olympics           6           FRA            Tennis
# 2       1920 Summer Olympics           7           FRA            Tennis
# 3       1920 Summer Olympics           7           FRA            Tennis
# 4       1920 Summer Olympics           7           FRA            Tennis
# ...                      ...         ...           ...               ...
# 314902  1900 Summer Olympics           2           GBR           Cricket
# 314903  1900 Summer Olympics           2           GBR           Cricket
# 314904  1900 Summer Olympics           2           GBR           Cricket
# 314905  1948 Summer Olympics          12           IRL         Athletics
# 314906  1924 Summer Olympics           8           NED  Art Competitions
#
#                   event                athlete  athlete_id medal  \
# 0          Singles, Men  Jean-François Blanchy           1   NaN
# 1          Doubles, Men  Jean-François Blanchy           1   NaN
# 2          Singles, Men  Jean-François Blanchy           1   NaN
# 3          Doubles, Men  Jean-François Blanchy           1   NaN
# 4        Doubles, Mixed  Jean-François Blanchy           1   NaN
# ...                 ...                    ...         ...   ...
# 314902     Cricket, Men           E. P. Daniel     3100007  Gold
# 314903     Cricket, Men          J. M. Willcox     3100008  Gold
# 314904     Cricket, Men            G. P. Brook     3100009  Gold
# 314905  800 metres, Men           Seamus Kelly     3100010   NaN
# 314906      Music, Open              Jaap Kool    22000000   NaN
#
#                          name   sex       born  height weight         country  \
# 0       Jean-François Blanchy  Male 1886-12-12     NaN    NaN          France
# 1       Jean-François Blanchy  Male 1886-12-12     NaN    NaN          France
# 2       Jean-François Blanchy  Male 1886-12-12     NaN    NaN          France
# 3       Jean-François Blanchy  Male 1886-12-12     NaN    NaN          France
# 4       Jean-François Blanchy  Male 1886-12-12     NaN    NaN          France
# ...                       ...   ...        ...     ...    ...             ...
# 314902           E. P. Daniel  Male        NaT     NaN    NaN   Great Britain
# 314903          J. M. Willcox  Male        NaT     NaN    NaN   Great Britain
# 314904            G. P. Brook  Male        NaT     NaN    NaN   Great Britain
# 314905           Seamus Kelly  Male        NaT     NaN    NaN         Ireland
# 314906              Jaap Kool  Male 1890-12-31     NaN    NaN     Netherlands
#
#        country_noc_y
# 0                FRA
# 1                FRA
# 2                FRA
# 3                FRA
# 4                FRA
# ...              ...
# 314902           GBR
# 314903           GBR
# 314904           GBR
# 314905           IRL
# 314906           NED
#
# [252859 rows x 15 columns]

# %%
# Confirm date type in born column in the summer_bio_results
summer_bio_results_csv.dtypes
# Out:
# edition                  object
# edition_id                int64
# country_noc_x            object
# sport                    object
# event                    object
# athlete                  object
# athlete_id                int64
# medal                    object
# name                     object
# sex                      object
# born             datetime64[ns]
# height                  float64
# weight                   object
# country                  object
# country_noc_y            object
# dtype: object

# %%
# Count valid entries per column in the summer_bio_results
summer_bio_results_csv.count()
# Out:
# edition          252859
# edition_id       252859
# country_noc_x    252859
# sport            252859
# event            252859
# athlete          252859
# athlete_id       252859
# medal             37281
# name             252859
# sex              252859
# born             243496
# height           179719
# weight           179719
# country          252859
# country_noc_y    252859
# dtype: int64

# %%
# Check and add start and end dates  for summer olympics that are missing based on the competition_date
olympics_games_csv.at[1, 'start_date'] = "14-May"
olympics_games_csv.at[1, 'end_date'] = "28-Oct"
olympics_games_csv.at[2, 'start_date'] = "1-Jul"
olympics_games_csv.at[2, 'end_date'] = "26-Nov"

# Only games held before 2024
olympics_games_csv = olympics_games_csv.loc[(olympics_games_csv['year'] < 2024) & (olympics_games_csv['isHeld'].isnull()), :]

olympics_games_csv.head()
# Out:
#                 edition  edition_id  edition_url  year       city  \
# 0  1896 Summer Olympics           1  /editions/1  1896     Athina
# 1  1900 Summer Olympics           2  /editions/2  1900      Paris
# 2  1904 Summer Olympics           3  /editions/3  1904  St. Louis
# 3  1908 Summer Olympics           5  /editions/5  1908     London
# 4  1912 Summer Olympics           6  /editions/6  1912  Stockholm
#
#                                     country_flag_url country_noc start_date  \
# 0  https://olympedia-flags.s3.eu-central-1.amazon...         GRE    6 April
# 1  https://olympedia-flags.s3.eu-central-1.amazon...         FRA     14-May
# 2  https://olympedia-flags.s3.eu-central-1.amazon...         USA      1-Jul
# 3  https://olympedia-flags.s3.eu-central-1.amazon...         GBR    13 July
# 4  https://olympedia-flags.s3.eu-central-1.amazon...         SWE     6 July
#
#    end_date       competition_date isHeld
# 0  15 April           6 – 13 April    NaN
# 1    28-Oct    14 May – 28 October    NaN
# 2    26-Nov   1 July – 26 November    NaN
# 3   25 July  27 April – 31 October    NaN
# 4   15 July        5 May – 27 July    NaN

# %%
# Filter to only summer olympics
summer_olympics_csv = olympics_games_csv.loc[(olympics_games_csv['edition'].str.contains('Summer')), ['edition', 'edition_id', 'year', 'city', 'country_noc', 'start_date', 'end_date']]
summer_olympics_csv
# Out:
#                  edition  edition_id  year              city country_noc  \
# 0   1896 Summer Olympics           1  1896            Athina         GRE
# 1   1900 Summer Olympics           2  1900             Paris         FRA
# 2   1904 Summer Olympics           3  1904         St. Louis         USA
# 3   1908 Summer Olympics           5  1908            London         GBR
# 4   1912 Summer Olympics           6  1912         Stockholm         SWE
# 6   1920 Summer Olympics           7  1920         Antwerpen         BEL
# 7   1924 Summer Olympics           8  1924             Paris         FRA
# 8   1928 Summer Olympics           9  1928         Amsterdam         NED
# 9   1932 Summer Olympics          10  1932       Los Angeles         USA
# 10  1936 Summer Olympics          11  1936            Berlin         GER
# 13  1948 Summer Olympics          12  1948            London         GBR
# 14  1952 Summer Olympics          13  1952          Helsinki         FIN
# 15  1956 Summer Olympics          14  1956         Melbourne         AUS
# 16  1960 Summer Olympics          15  1960              Roma         ITA
# 17  1964 Summer Olympics          16  1964             Tokyo         JPN
# 18  1968 Summer Olympics          17  1968  Ciudad de México         MEX
# 19  1972 Summer Olympics          18  1972           München         FRG
# 20  1976 Summer Olympics          19  1976          Montréal         CAN
# 21  1980 Summer Olympics          20  1980            Moskva         URS
# 22  1984 Summer Olympics          21  1984       Los Angeles         USA
# 23  1988 Summer Olympics          22  1988             Seoul         KOR
# 24  1992 Summer Olympics          23  1992         Barcelona         ESP
# 25  1996 Summer Olympics          24  1996           Atlanta         USA
# 26  2000 Summer Olympics          25  2000            Sydney         AUS
# 27  2004 Summer Olympics          26  2004            Athina         GRE
# 28  2008 Summer Olympics          53  2008           Beijing         CHN
# 29  2012 Summer Olympics          54  2012            London         GBR
# 30  2016 Summer Olympics          59  2016    Rio de Janeiro         BRA
# 31  2020 Summer Olympics          61  2020             Tokyo         JPN
#
#       start_date        end_date
# 0        6 April        15 April
# 1         14-May          28-Oct
# 2          1-Jul          26-Nov
# 3        13 July         25 July
# 4         6 July         15 July
# 6      14 August       30 August
# 7         5 July         27 July
# 8        28 July       12 August
# 9        30 July       14 August
# 10      1 August       16 August
# 13       29 July       14 August
# 14       19 July        3 August
# 15   22 November      8 December
# 16     25 August    11 September
# 17    10 October      24 October
# 18    12 October      27 October
# 19     26 August    11 September
# 20       17 July        1 August
# 21       19 July        3 August
# 22       28 July       12 August
# 23  17 September       2 October
# 24       25 July        9 August
# 25       19 July        4 August
# 26  15 September       1 October
# 27     13 August       29 August
# 28      8 August       24 August
# 29       27 July       12 August
# 30      5 August       21 August
# 31  23 July 2021   8 August 2021

# %%
# Merge start_date with year and force the date format
# Convert year int to str
summer_olympics_csv = summer_olympics_csv.astype({'year': str}, errors='raise')

# Join start_date with year
summer_olympics_csv['final_start_date'] = summer_olympics_csv['start_date'] + ' ' + summer_olympics_csv['year']

# Apply date format function
summer_olympics_csv['final_start_date'] = summer_olympics_csv['final_start_date'].apply(convert_to_datetime)

# Drop original start_date column
summer_olympics_csv = summer_olympics_csv.drop('start_date', axis=1)
summer_olympics_csv
# Out:
#                  edition  edition_id  year              city country_noc  \
# 0   1896 Summer Olympics           1  1896            Athina         GRE
# 1   1900 Summer Olympics           2  1900             Paris         FRA
# 2   1904 Summer Olympics           3  1904         St. Louis         USA
# 3   1908 Summer Olympics           5  1908            London         GBR
# 4   1912 Summer Olympics           6  1912         Stockholm         SWE
# 6   1920 Summer Olympics           7  1920         Antwerpen         BEL
# 7   1924 Summer Olympics           8  1924             Paris         FRA
# 8   1928 Summer Olympics           9  1928         Amsterdam         NED
# 9   1932 Summer Olympics          10  1932       Los Angeles         USA
# 10  1936 Summer Olympics          11  1936            Berlin         GER
# 13  1948 Summer Olympics          12  1948            London         GBR
# 14  1952 Summer Olympics          13  1952          Helsinki         FIN
# 15  1956 Summer Olympics          14  1956         Melbourne         AUS
# 16  1960 Summer Olympics          15  1960              Roma         ITA
# 17  1964 Summer Olympics          16  1964             Tokyo         JPN
# 18  1968 Summer Olympics          17  1968  Ciudad de México         MEX
# 19  1972 Summer Olympics          18  1972           München         FRG
# 20  1976 Summer Olympics          19  1976          Montréal         CAN
# 21  1980 Summer Olympics          20  1980            Moskva         URS
# 22  1984 Summer Olympics          21  1984       Los Angeles         USA
# 23  1988 Summer Olympics          22  1988             Seoul         KOR
# 24  1992 Summer Olympics          23  1992         Barcelona         ESP
# 25  1996 Summer Olympics          24  1996           Atlanta         USA
# 26  2000 Summer Olympics          25  2000            Sydney         AUS
# 27  2004 Summer Olympics          26  2004            Athina         GRE
# 28  2008 Summer Olympics          53  2008           Beijing         CHN
# 29  2012 Summer Olympics          54  2012            London         GBR
# 30  2016 Summer Olympics          59  2016    Rio de Janeiro         BRA
# 31  2020 Summer Olympics          61  2020             Tokyo         JPN
#
#           end_date    final_start_date
# 0         15 April 1896-04-06 00:00:00
# 1           28-Oct 1900-05-14 00:00:00
# 2           26-Nov 1904-07-01 00:00:00
# 3          25 July 1908-07-13 00:00:00
# 4          15 July 1912-07-06 00:00:00
# 6        30 August 1920-08-14 00:00:00
# 7          27 July 1924-07-05 00:00:00
# 8        12 August 1928-07-28 00:00:00
# 9        14 August 1932-07-30 00:00:00
# 10       16 August 1936-08-01 00:00:00
# 13       14 August 1948-07-29 00:00:00
# 14        3 August 1952-07-19 00:00:00
# 15      8 December 1956-11-22 00:00:00
# 16    11 September 1960-08-25 00:00:00
# 17      24 October 1964-10-10 00:00:00
# 18      27 October 1968-10-12 00:00:00
# 19    11 September 1972-08-26 00:00:00
# 20        1 August 1976-07-17 00:00:00
# 21        3 August 1980-07-19 00:00:00
# 22       12 August 1984-07-28 00:00:00
# 23       2 October 1988-09-17 00:00:00
# 24        9 August 1992-07-25 00:00:00
# 25        4 August 1996-07-19 00:00:00
# 26       1 October 2000-09-15 00:00:00
# 27       29 August 2004-08-13 00:00:00
# 28       24 August 2008-08-08 00:00:00
# 29       12 August 2012-07-27 00:00:00
# 30       21 August 2016-08-05 00:00:00
# 31   8 August 2021 2021-07-23 20:20:00

# %%
summer_olympics_csv.dtypes
# Out:
# edition                     object
# edition_id                   int64
# year                        object
# city                        object
# country_noc                 object
# end_date                    object
# final_start_date    datetime64[ns]
# dtype: object

# %%
# Merge summer athletes df and olympics df
summer_bio_results_olympics_csv = pd.merge(summer_bio_results_csv, summer_olympics_csv, on=['edition_id','edition'], how='outer')
summer_bio_results_olympics_csv.tail()
# Out:
#                      edition  edition_id country_noc_x                sport  \
# 252854  2020 Summer Olympics          61           USA            Taekwondo
# 252855  2020 Summer Olympics          61           UZB            Athletics
# 252856  2020 Summer Olympics          61           UZB  Rhythmic Gymnastics
# 252857  2020 Summer Olympics          61           UZB             Swimming
# 252858  2020 Summer Olympics          61           UZB        Weightlifting
#
#                              event                  athlete  athlete_id medal  \
# 252854        Featherweight, Women       Anastasija Zolotic     2506221  Gold
# 252855          Triple Jump, Women      Roksana Khudoyarova     2506229   NaN
# 252856           Individual, Women      Yekaterina Fetisova     2506234   NaN
# 252857  50 metres Freestyle, Women        Natalya Kritinina     2506239   NaN
# 252858    Light-Heavyweight, Women  Kumushkhon Fayzullayeva     2506242   NaN
#
#                            name     sex       born  height weight  \
# 252854       Anastasija Zolotic  Female 2002-11-23     NaN    NaN
# 252855      Roksana Khudoyarova  Female 2001-01-30     NaN    NaN
# 252856      Yekaterina Fetisova  Female 2003-01-03     NaN    NaN
# 252857        Natalya Kritinina  Female 2001-01-06   176.0     64
# 252858  Kumushkhon Fayzullayeva  Female 2002-01-20     NaN    NaN
#
#                country country_noc_y  year   city country_noc        end_date  \
# 252854   United States           USA  2020  Tokyo         JPN   8 August 2021
# 252855      Uzbekistan           UZB  2020  Tokyo         JPN   8 August 2021
# 252856      Uzbekistan           UZB  2020  Tokyo         JPN   8 August 2021
# 252857      Uzbekistan           UZB  2020  Tokyo         JPN   8 August 2021
# 252858      Uzbekistan           UZB  2020  Tokyo         JPN   8 August 2021
#
#           final_start_date
# 252854 2021-07-23 20:20:00
# 252855 2021-07-23 20:20:00
# 252856 2021-07-23 20:20:00
# 252857 2021-07-23 20:20:00
# 252858 2021-07-23 20:20:00

# %%
# Confirm it's the lame length on this merged df
len(summer_bio_results_olympics_csv)
# Out:
# 252859

# %%
summer_bio_results_olympics_csv.dtypes
# Out:
# edition                     object
# edition_id                   int64
# country_noc_x               object
# sport                       object
# event                       object
# athlete                     object
# athlete_id                   int64
# medal                       object
# name                        object
# sex                         object
# born                datetime64[ns]
# height                     float64
# weight                      object
# country                     object
# country_noc_y               object
# year                        object
# city                        object
# country_noc                 object
# end_date                    object
# final_start_date    datetime64[ns]
# dtype: object

# %%
# Add athlete age column
summer_bio_results_olympics_csv['athlete_age'] = round((summer_bio_results_olympics_csv['final_start_date'] - summer_bio_results_olympics_csv['born']).dt.days / 365,0)
summer_bio_results_olympics_csv
# Out:
#                      edition  edition_id country_noc_x                sport  \
# 0       1896 Summer Olympics           1           FRA               Tennis
# 1       1896 Summer Olympics           1           FRA               Tennis
# 2       1896 Summer Olympics           1           GER               Tennis
# 3       1896 Summer Olympics           1           GBR               Tennis
# 4       1896 Summer Olympics           1           GBR               Tennis
# ...                      ...         ...           ...                  ...
# 252854  2020 Summer Olympics          61           USA            Taekwondo
# 252855  2020 Summer Olympics          61           UZB            Athletics
# 252856  2020 Summer Olympics          61           UZB  Rhythmic Gymnastics
# 252857  2020 Summer Olympics          61           UZB             Swimming
# 252858  2020 Summer Olympics          61           UZB        Weightlifting
#
#                              event                  athlete  athlete_id medal  \
# 0                     Singles, Men                J. Defert          13   NaN
# 1                     Doubles, Men                J. Defert          13   NaN
# 2                     Doubles, Men         John Pius Boland          79  Gold
# 3                     Singles, Men         John Pius Boland          79  Gold
# 4                     Doubles, Men         John Pius Boland          79  Gold
# ...                            ...                      ...         ...   ...
# 252854        Featherweight, Women       Anastasija Zolotic     2506221  Gold
# 252855          Triple Jump, Women      Roksana Khudoyarova     2506229   NaN
# 252856           Individual, Women      Yekaterina Fetisova     2506234   NaN
# 252857  50 metres Freestyle, Women        Natalya Kritinina     2506239   NaN
# 252858    Light-Heavyweight, Women  Kumushkhon Fayzullayeva     2506242   NaN
#
#                            name     sex  ... height  weight         country  \
# 0                     J. Defert    Male  ...    NaN     NaN          France
# 1                     J. Defert    Male  ...    NaN     NaN          France
# 2              John Pius Boland    Male  ...    NaN     NaN   Great Britain
# 3              John Pius Boland    Male  ...    NaN     NaN   Great Britain
# 4              John Pius Boland    Male  ...    NaN     NaN   Great Britain
# ...                         ...     ...  ...    ...     ...             ...
# 252854       Anastasija Zolotic  Female  ...    NaN     NaN   United States
# 252855      Roksana Khudoyarova  Female  ...    NaN     NaN      Uzbekistan
# 252856      Yekaterina Fetisova  Female  ...    NaN     NaN      Uzbekistan
# 252857        Natalya Kritinina  Female  ...  176.0      64      Uzbekistan
# 252858  Kumushkhon Fayzullayeva  Female  ...    NaN     NaN      Uzbekistan
#
#        country_noc_y  year    city country_noc        end_date  \
# 0                FRA  1896  Athina         GRE        15 April
# 1                FRA  1896  Athina         GRE        15 April
# 2                GBR  1896  Athina         GRE        15 April
# 3                GBR  1896  Athina         GRE        15 April
# 4                GBR  1896  Athina         GRE        15 April
# ...              ...   ...     ...         ...             ...
# 252854           USA  2020   Tokyo         JPN   8 August 2021
# 252855           UZB  2020   Tokyo         JPN   8 August 2021
# 252856           UZB  2020   Tokyo         JPN   8 August 2021
# 252857           UZB  2020   Tokyo         JPN   8 August 2021
# 252858           UZB  2020   Tokyo         JPN   8 August 2021
#
#           final_start_date athlete_age
# 0      1896-04-06 00:00:00         NaN
# 1      1896-04-06 00:00:00         NaN
# 2      1896-04-06 00:00:00        26.0
# 3      1896-04-06 00:00:00        26.0
# 4      1896-04-06 00:00:00        26.0
# ...                    ...         ...
# 252854 2021-07-23 20:20:00        19.0
# 252855 2021-07-23 20:20:00        20.0
# 252856 2021-07-23 20:20:00        19.0
# 252857 2021-07-23 20:20:00        21.0
# 252858 2021-07-23 20:20:00        20.0
#
# [252859 rows x 21 columns]
